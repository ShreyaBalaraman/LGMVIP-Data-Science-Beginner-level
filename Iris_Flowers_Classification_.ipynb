# %% [markdown]
#   LGMVIP-DataScience Internship - January 2022

# %% [markdown]
# TASK-1 Iris Flowers Classification ML Project

# %% [markdown]
# Author - Shreya Balaraman

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd  
import numpy as np 
import os 
from google.colab import files
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
import plotly.express as px
from sklearn.model_selection import train_test_split 
from sklearn import metrics
# %matplotlib inline

# %% [markdown]
# Loading DataSet

# %%
iris=pd.read_csv("Iris.csv")

# %% [markdown]
# Summarizing Dataset

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [5 rows x 6 columns]

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
print(iris.info)
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]>

# %%
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# Processing the dataset

# %%
iris.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
iris.shape
# Out:
# (150, 6)

# %% [markdown]
# Data Visualization

# %%
iris.hist(edgecolor='Red',linewidth=1.4,figsize=(9,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f88c86c1f10>,
# ...
#       dtype=object)

# %% [markdown]
# Pair plot - Plotting multiple pairwise bivariate distributions in a dataset

# %%
seabornInstance.pairplot(iris,hue='Species',height=3,aspect=1)

# %% [markdown]
# Violin plot - To check the comparison of a variable distribution

# %%
seabornInstance.violinplot(y='Species', x='SepalLengthCm', data=iris,inner='quartile')
plt.show()
seabornInstance.violinplot(y='Species', x='SepalWidthCm', data=iris, inner='quartile')
plt.show()
seabornInstance.violinplot(y='Species', x='PetalLengthCm',data=iris, inner='quartile')
plt.show()
seabornInstance.violinplot(y='Species', x='PetalWidthCm', data=iris, inner='quartile')
plt.show()

# %% [markdown]
# Heatmap - Plotting the heatmap to check the correlation.

# %%
iris.corr()
# Out:
#                      Id  SepalLengthCm  ...  PetalLengthCm  PetalWidthCm
# Id             1.000000       0.716676  ...       0.882747      0.899759
# SepalLengthCm  0.716676       1.000000  ...       0.871754      0.817954
# SepalWidthCm  -0.397729      -0.109369  ...      -0.420516     -0.356544
# PetalLengthCm  0.882747       0.871754  ...       1.000000      0.962757
# PetalWidthCm   0.899759       0.817954  ...       0.962757      1.000000
#
# [5 rows x 5 columns]

# %%
plt.figure(figsize=(6,5))
seabornInstance.heatmap(iris.corr(), annot=True, cmap='cubehelix_r')
plt.show()

# %% [markdown]
# Scatter plot -
# It plots the iris species according to the sepal length and sepal width

# %%
fig = px.scatter(iris, x="SepalLengthCm", y="SepalWidthCm", color="Species")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="85c9a15a-4905-486a-a95b-1fbf3621ed2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("85c9a15a-4905-486a-a95b-1fbf3621ed2e")) {
#                     Plotly.newPlot(
#                         '85c9a15a-4905-486a-a95b-1fbf3621ed2e',
# ...

# %% [markdown]
# Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()

# %%
iris['Species']=label.fit_transform(iris['Species'])
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        0
# 1   2            4.9           3.0            1.4           0.2        0
# 2   3            4.7           3.2            1.3           0.2        0
# 3   4            4.6           3.1            1.5           0.2        0
# 4   5            5.0           3.6            1.4           0.2        0

# %% [markdown]
# Model Training

# %%
X=iris.drop(columns=['Species'])
y=iris['Species']
X_train, X_test, y_train, y_test= train_test_split(X,y,test_size=0.30,random_state=1)

# %%
from sklearn.svm import SVC
svn = SVC()
svn.fit(X_train, y_train)

# %% [markdown]
# Model Evaluation

# %%
from sklearn.metrics import accuracy_score
predictions = svn.predict(X_test)
print("Accuracy:",accuracy_score(y_test, predictions))
# Out:
# Accuracy: 0.9777777777777777

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        14
#            1       1.00      0.94      0.97        18
#            2       0.93      1.00      0.96        13
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
